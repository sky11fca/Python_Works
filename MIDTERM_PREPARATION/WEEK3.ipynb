# %% [markdown]
# # Python Sets and Dictionaries

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Given 2 lists, will return a list of sets consisting of `[a | b, a & b, a-b, b-a]`

# %%
def set_operations(a, b):
    return [set(a) | set(b), set(a) & set(b), set(a) - set(b), set(b) - set(a)]
