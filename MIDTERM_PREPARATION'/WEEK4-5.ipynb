# %% [markdown]
# # Python OOP

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Class `stack`
#
# ATTRIBUTES:
#
# - list
#
# METHODS:
#
# - push
# - pop (handle empty stack)
# - peek (handle empty stack)
